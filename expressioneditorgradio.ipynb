# %% [markdown]
# <a href="https://colab.research.google.com/github/nmjp8989/aseprite-builder/blob/main/expressioneditorgradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Avoid cv2 namespace clash with Colab's preinstalled opencv
# !pip uninstall -y opencv-python opencv-python-headless -q

# !pip install -q "numpy>=1.26.4" opencv-python-headless "imageio-ffmpeg>=0.5.1" \
    "lmdb>=1.4.1" "timm>=1.0.7" "rich>=13.7.1" "albumentations>=1.4.10" \
    ultralytics tyro dill PyYAML safetensors Pillow
# !pip install -q gradio

# !wget -q https://huggingface.co/spaces/fffiloni/expression-editor/raw/main/app.py

# Remove HuggingFace ZeroGPU-specific lines (not needed on Colab)
# !sed -i '/^import spaces$/d' app.py
# !sed -i '/@spaces.GPU/d' app.py

# Expose a public Gradio link so you can use the UI from your browser
# !sed -i 's/demo.queue().launch()/demo.queue().launch(share=True, server_name="0.0.0.0")/' app.py

# !python app.py
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 MB 18.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.7/344.7 kB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 MB 10.1 MB/s eta 0:00:00
# Cloning into '/content/advanced_live_portrait'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 72 (delta 4), reused 58 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (72/72), 14.13 MiB | 48.07 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# Creating new Ultralytics Settings v0.0.7 file ✅
# ...
